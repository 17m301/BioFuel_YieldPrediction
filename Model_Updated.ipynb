# %%
import pandas as pd
url = "https://raw.githubusercontent.com/17m301/BioFuel_YieldPrediction/main/Datasets/Train/Trainset_dataset1.xlsx"
df_train = pd.read_excel(url)
df_train.info()
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ash(wt%)                   747 non-null    float64
#  1   FixedCarbon(wt%)           747 non-null    float64
#  2   Volatiles(wt%)             747 non-null    float64
#  3   C(wt%)                     845 non-null    float64
#  4   H(wt%)                     835 non-null    float64
#  5   O(wt%)                     835 non-null    float64
#  6   N(wt%)                     805 non-null    float64
#  7   H/C                        835 non-null    float64
#  8   Cellulose(wt%)             669 non-null    float64
#  9   Hemicellulose(wt%)         483 non-null    float64
#  10  Lignin(wt%)                510 non-null    float64
#  11  T(^C)                      845 non-null    int64
#  12  HeatingRate(^C/min)        845 non-null    int64
#  13  ParticleSize(mm)           845 non-null    float64
#  14  FlowRate-Nitrogen(ml/min)  845 non-null    int64
#  15  yield(wt%)                 845 non-null    float64
# dtypes: float64(13), int64(3)
# memory usage: 105.8 KB
#     Ash(wt%)  FixedCarbon(wt%)  Volatiles(wt%)  C(wt%)  H(wt%)  O(wt%)  \
# 0   9.024134         13.850997       77.124869   52.05    5.37   42.10
# 1   5.676433          5.353296       88.970271   42.72    5.61   51.24
# 2  13.538462         13.098901       73.362637   40.40    5.58   52.09
# 3   4.641028         12.844536       82.514435   43.76    6.30   49.57
# 4        NaN               NaN             NaN   45.92    6.23   33.17
#
#    N(wt%)  H/C  Cellulose(wt%)  Hemicellulose(wt%)  Lignin(wt%)  T(^C)  \
# 0    0.49  0.1           27.70               21.60        44.00    500
# 1    0.44  0.1           34.44               23.94        35.89    500
# 2    1.94  0.1           32.49               22.97        26.00    500
# 3    0.38  0.1           46.10               23.17        29.31    500
# 4    6.74  0.1           28.52               41.48         4.91    400
#
#    HeatingRate(^C/min)  ParticleSize(mm)  FlowRate-Nitrogen(ml/min)  \
# 0                   10              1.50                        200
# 1                   10              1.50                        200
# 2                   10              1.50                        200
# 3                   10              1.50                        200
# 4                   20              0.25                        100
#
#    yield(wt%)
# 0        47.4
# 1        40.9
# 2        16.6
# 3        28.9
# 4        46.8

# %% [markdown]
# Understanding the data

# %%
df_train.shape #how big is the data?
df_train.sample(5) #printing random 5 data
df_train.info()# datatype of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ash(wt%)                   747 non-null    float64
#  1   FixedCarbon(wt%)           747 non-null    float64
#  2   Volatiles(wt%)             747 non-null    float64
#  3   C(wt%)                     845 non-null    float64
#  4   H(wt%)                     835 non-null    float64
#  5   O(wt%)                     835 non-null    float64
#  6   N(wt%)                     805 non-null    float64
#  7   H/C                        835 non-null    float64
#  8   Cellulose(wt%)             669 non-null    float64
#  9   Hemicellulose(wt%)         483 non-null    float64
#  10  Lignin(wt%)                510 non-null    float64
#  11  T(^C)                      845 non-null    int64
#  12  HeatingRate(^C/min)        845 non-null    int64
#  13  ParticleSize(mm)           845 non-null    float64
#  14  FlowRate-Nitrogen(ml/min)  845 non-null    int64
#  15  yield(wt%)                 845 non-null    float64
# dtypes: float64(13), int64(3)
# memory usage: 105.8 KB

# %% [markdown]
# Find out Total Missing values of each column

# %%
df_train.isnull().sum()
# Out:
# Ash(wt%)                      98
# FixedCarbon(wt%)              98
# Volatiles(wt%)                98
# C(wt%)                         0
# H(wt%)                        10
# O(wt%)                        10
# N(wt%)                        40
# H/C                           10
# Cellulose(wt%)               176
# Hemicellulose(wt%)           362
# Lignin(wt%)                  335
# T(^C)                          0
# HeatingRate(^C/min)            0
# ParticleSize(mm)               0
# FlowRate-Nitrogen(ml/min)      0
# yield(wt%)                     0
# dtype: int64

# %%
df_train.duplicated().sum()
df_train[df_train.duplicated()] # Print the duplicates
# Out:
#      Ash(wt%)  FixedCarbon(wt%)  Volatiles(wt%)  C(wt%)  H(wt%)  O(wt%)  \
# 343  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 410  6.700799         14.741558       78.557643   53.60    8.30   35.90
# 414  6.163938         15.409846       78.426216   49.60    7.40   38.50
# 415  6.163938         15.409846       78.426216   49.60    7.40   38.50
# 416  0.753000         18.602000       80.645000   51.30    5.00   43.20
# 418  0.753000         18.602000       80.645000   51.30    5.00   43.20
# 419  6.700799         14.741558       78.557643   53.60    8.30   35.90
# 421  6.163938         15.409846       78.426216   49.60    7.40   38.50
# 441  8.352000         12.586000       79.062000   54.10    6.12   34.53
# 446  8.352000         12.586000       79.062000   54.10    6.12   34.53
# 448  2.330233         11.981198       85.688569   60.46    9.08   27.36
# 452  2.330233         11.981198       85.688569   60.46    9.08   27.36
# 458  2.330233         11.981198       85.688569   60.46    9.08   27.36
# 460  2.330233         11.981198       85.688569   60.46    9.08   27.36
# 473  4.139000         17.114000       78.747000   44.82    5.08   49.18
# 474  4.139000         17.114000       78.747000   44.82    5.08   49.18
# 475  4.139000         17.114000       78.747000   44.82    5.08   49.18
# 477  4.139000         17.114000       78.747000   44.82    5.08   49.18
# 478  4.139000         17.114000       78.747000   44.82    5.08   49.18
# 479  4.139000         17.114000       78.747000   44.82    5.08   49.18
# 497  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 498  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 499  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 500  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 501  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 503  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 504  6.678500         15.487020       77.834480   51.15    5.89   40.84
# 534  6.421000         11.053000       82.526000   53.20    7.10   31.70
# 537  6.421000         11.053000       82.526000   53.20    7.10   31.70
# 565  7.261774         10.810515       81.927711   52.43    6.09   40.86
# 566  7.261774         10.810515       81.927711   52.43    6.09   40.86
# 567  7.261774         10.810515       81.927711   52.43    6.09   40.86
# 764  1.934052         14.880575       83.185373   49.65    7.54   38.13
# 765  1.934052         14.880575       83.185373   49.65    7.54   38.13
# 766  1.934052         14.880575       83.185373   49.65    7.54   38.13
# 790  7.046192         17.671401       75.282407   45.92    6.21   40.09
# 791  7.046192         17.671401       75.282407   45.92    6.21   40.09
#
#      N(wt%)  H/C  Cellulose(wt%)  Hemicellulose(wt%)  Lignin(wt%)  T(^C)  \
# 343    2.12  0.1           30.69               33.61        16.14    600
# 410    2.20  0.2             NaN                 NaN          NaN    550
# 414    4.40  0.1             NaN                 NaN          NaN    550
# 415    4.40  0.1             NaN                 NaN          NaN    700
# 416    0.50  0.1             NaN                 NaN          NaN    400
# 418    0.50  0.1             NaN                 NaN          NaN    700
# 419    2.20  0.2             NaN                 NaN          NaN    500
# 421    4.40  0.1             NaN                 NaN          NaN    550
# 441    5.23  0.1           20.00               24.00        15.00    500
# 446    5.23  0.1           20.00               24.00        15.00    500
# 448    3.10  0.2           20.00                 NaN          NaN    400
# 452    3.10  0.2           20.00                 NaN          NaN    700
# 458    3.10  0.2           20.00                 NaN          NaN    550
# 460    3.10  0.2           20.00                 NaN          NaN    700
# 473    0.92  0.1           56.00                 NaN          NaN    400
# 474    0.92  0.1           56.00                 NaN          NaN    500
# 475    0.92  0.1           56.00                 NaN          NaN    550
# 477    0.92  0.1           56.00                 NaN          NaN    500
# 478    0.92  0.1           56.00                 NaN          NaN    500
# 479    0.92  0.1           56.00                 NaN          NaN    500
# 497    2.12  0.1           30.69               33.61        16.14    500
# 498    2.12  0.1           30.69               33.61        16.14    600
# 499    2.12  0.1           30.69               33.61        16.14    600
# 500    2.12  0.1           30.69               33.61        16.14    600
# 501    2.12  0.1           30.69               33.61        16.14    600
# 503    2.12  0.1           30.69               33.61        16.14    600
# 504    2.12  0.1           30.69               33.61        16.14    600
# 534    8.00  0.1             NaN                 NaN          NaN    500
# 537    8.00  0.1             NaN                 NaN          NaN    400
# 565    0.62  0.1           48.00                 NaN          NaN    550
# 566    0.62  0.1           48.00                 NaN          NaN    550
# 567    0.62  0.1           48.00                 NaN          NaN    550
# 764    4.03  0.2           26.98               25.52        39.67    400
# 765    4.03  0.2           26.98               25.52        39.67    600
# 766    4.03  0.2           26.98               25.52        39.67    800
# 790    6.90  0.1           28.58               41.40         4.99    400
# 791    6.90  0.1           28.58               41.40         4.99    450
#
#      HeatingRate(^C/min)  ParticleSize(mm)  FlowRate-Nitrogen(ml/min)  \
# 343                  200            0.2000                        150
# 410                    7            0.5500                        400
# 414                    7            0.6375                        200
# 415                    7            0.6375                        200
# 416                    7            0.6375                        100
# 418                    7            0.6375                        100
# 419                    7            0.5500                        100
# 421                    7            0.6375                        400
# 441                   25            0.2000                        100
# 446                   25            0.2000                        300
# 448                    5            1.2000                          0
# 452                    5            1.2000                          0
# 458                   80            1.2000                          0
# 460                   80            1.2000                          0
# 473                    7            1.2900                          0
# 474                    7            1.2900                          0
# 475                    7            1.2900                          0
# 477                    7            1.2900                        100
# 478                    7            1.2900                        200
# 479                    7            1.2900                        400
# 497                  200            0.2000                        200
# 498                  200            0.2000                        200
# 499                  200            0.1500                        200
# 500                  200            0.3375                        200
# 501                  200            0.7125                        200
# 503                  200            0.2000                        150
# 504                  200            0.2000                        250
# 534                    7            0.6375                          0
# 537                   40            0.6375                          0
# 565                  300            0.6375                          0
# 566                  100            0.6375                          0
# 567                  700            0.6375                          0
# 764                    5            3.2000                         30
# 765                    5            3.2000                         30
# 766                    5            3.2000                         30
# 790                    5            2.0000                         30
# 791                    5            2.0000                         30
#
#      yield(wt%)
# 343        50.7
# 410        46.3
# 414        57.1
# 415        49.9
# 416        33.0
# 418        33.9
# 419        46.9
# 421        54.5
# 441        49.0
# 446        38.0
# 448        46.5
# 452        39.9
# 458        47.0
# 460        44.0
# 473        28.7
# 474        32.7
# 475        31.0
# 477        38.1
# 478        39.2
# 479        37.3
# 497        48.9
# 498        52.3
# 499        51.5
# 500        52.1
# 501        51.7
# 503        50.7
# 504        52.8
# 534        49.5
# 537        45.3
# 565        35.5
# 566        32.8
# 567        36.6
# 764        42.2
# 765        54.2
# 766        52.1
# 790        53.9
# 791        58.0

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
#  44%|████▍     | 7/16 [00:00<00:00, 59.57it/s]
# 100%|██████████| 16/16 [00:00<00:00, 59.57it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# EDA

# %% [markdown]
# Univariant Analysis

# %%
import matplotlib.pyplot as plt
plt.hist(df_train['yield(wt%)'])
# Out:
# (array([  5.,  36., 106., 193., 211., 155., 101.,  36.,   1.,   1.]),
#  array([11.  , 17.62, 24.24, 30.86, 37.48, 44.1 , 50.72, 57.34, 63.96,
#         70.58, 77.2 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Feature Scaling
# Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
#fitting the scaler to the training set to learn the parameter
scaler.fit(df_train)
#Now transform the train set
df_train_scaled=scaler.transform(df_train)

#above step will return numpy array so we need to transform this to DataFrame
df_train_scaled=pd.DataFrame(df_train_scaled,columns=df_train.columns)
df_train_scaled.describe()

#Standardization used for K Means, KNN, ANN, GD and PCA
#algo which uses distance to measure similarity which will affect when the data is having huge range difference, so we need to regularize
# Out:
#            Ash(wt%)  FixedCarbon(wt%)  Volatiles(wt%)        C(wt%)  \
# count  7.470000e+02      7.470000e+02    7.470000e+02  8.450000e+02
# mean  -4.755975e-17     -5.707171e-17    5.992529e-16  5.928197e-16
# std    1.000670e+00      1.000670e+00    1.000670e+00  1.000592e+00
# min   -1.415443e+00     -1.866147e+00   -6.772507e+00 -4.443501e+00
# 25%   -8.713913e-01     -4.748821e-01   -2.576669e-01 -6.636092e-01
# 50%   -1.000917e-01     -1.351655e-01    4.063053e-02 -2.786064e-01
# 75%    4.403835e-01      1.265332e-01    4.777015e-01  5.421361e-01
# max    9.125892e+00      7.324416e+00    1.770428e+00  4.551836e+00
#
#              H(wt%)        O(wt%)      N(wt%)           H/C  Cellulose(wt%)  \
# count  8.350000e+02  8.350000e+02  805.000000  8.350000e+02    6.690000e+02
# mean  -2.595396e-16 -9.360443e-16    0.000000 -2.637943e-16   -1.327621e-16
# std    1.000599e+00  1.000599e+00    1.000622  1.000599e+00    1.000748e+00
# min   -3.525390e+00 -3.497731e+00   -1.083642 -5.279334e-01   -2.459289e+00
# 25%   -5.125699e-01 -7.444763e-01   -0.789517 -5.279334e-01   -6.022396e-01
# 50%   -2.182139e-01  1.198367e-01   -0.346369 -5.279334e-01   -1.814816e-01
# 75%    2.195974e-01  8.923745e-01    0.575221 -5.279334e-01    7.656568e-01
# max    3.556469e+00  1.570814e+00    2.492914  1.894178e+00    2.260820e+00
#
#        Hemicellulose(wt%)   Lignin(wt%)         T(^C)  HeatingRate(^C/min)  \
# count        4.830000e+02  5.100000e+02  8.450000e+02         8.450000e+02
# mean         3.677757e-17 -3.483053e-17  6.222504e-16         2.522637e-17
# std          1.001037e+00  1.000982e+00  1.000592e+00         1.000592e+00
# min         -2.253492e+00 -1.893588e+00 -2.367860e+00        -5.365903e-01
# 25%         -7.579656e-01 -6.639490e-01 -7.133603e-01        -5.187258e-01
# 50%         -1.859267e-01  2.981136e-01 -1.618603e-01        -4.026066e-01
# 75%          8.450517e-01  6.436248e-01  3.896396e-01        -1.346391e-01
# max          2.227479e+00  2.401489e+00  4.250139e+00         6.564548e+00
#
#        ParticleSize(mm)  FlowRate-Nitrogen(ml/min)    yield(wt%)
# count      8.450000e+02               8.450000e+02  8.450000e+02
# mean       1.093143e-16               3.363516e-17 -5.297538e-16
# std        1.000592e+00               1.000592e+00  1.000592e+00
# min       -1.352612e+00              -5.174337e-01 -2.978555e+00
# 25%       -6.879232e-01              -5.174337e-01 -7.556636e-01
# 50%       -3.081010e-01              -1.040738e-01 -1.806772e-02
# 75%        3.565879e-01              -1.040738e-01  7.397363e-01
# max        4.534632e+00               7.749766e+00  3.710328e+00

# %% [markdown]
# # Effect of Scaling

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
ax1.scatter(df_train['FixedCarbon(wt%)'], df_train['yield(wt%)'])
ax1.set_title('Before Scaling')
ax2.scatter(df_train_scaled['FixedCarbon(wt%)'], df_train_scaled['yield(wt%)'])
ax2.set_title('After Scaling')
plt.show()
